# %%
import sys
sys.path.append('../scripts')
import plot

# %%
app_visualizer = plot.AppDataVisualizer()

# %% [markdown]
# #### Visualizations for Google Play app metadata such as score, ratings, reviews, installs.

# %%
app_visualizer.plot_app_scores()

# %%
app_visualizer.plot_num_ratings()

# %%
app_visualizer.plot_num_reviews()

# %%
app_visualizer.plot_num_installs()

# %% [markdown]
# #### Visualizations fpr Play Store review data per banking app.

# %%
review_visualizer = plot.ReviewDataVisualizer()

# %%
review_visualizer.load_data()

# %%
review_visualizer.plot_rating_distribution()

# %%
review_visualizer.plot_review_counts_over_time()
